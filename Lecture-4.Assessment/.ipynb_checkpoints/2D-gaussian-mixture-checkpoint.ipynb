# %%
import stan
import pandas as pd
import numpy as np
import scipy.stats as stats 
import matplotlib
import matplotlib.pyplot as plt
import arviz as az
#matplotlib.rcParams['figure.figsize']=5,5
matplotlib.rcParams['figure.dpi']=100
#plt.style.use('ggplot')

# %%
# this is a work around found at 
# https://stackoverflow.com/questions/56154176/runtimeerror-asyncio-run-cannot-be-called-from-a-running-event-loop-in-spyd
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### Generate data

# %%
muA1 = 8
sigmaA1 = 2
muB1 = 3
sigmaB1  = 2

muA2 = 24
sigmaA2 = 4
muB2 = 17
sigmaB2  = 3

pi0 = 0.2

N = 500

# %%
mydata = []
classes = np.random.binomial(1,pi0,N)
for n in range(N):
    if classes[n]:
        mydata.append([np.random.normal(muA1,sigmaA1),np.random.normal(muB1,sigmaB1),classes[n]])
    else:
        mydata.append([np.random.normal(muA2,sigmaA2),np.random.normal(muB2,sigmaB2),classes[n]])

# %%
colors=['red','blue']
colors=['red','blue']
for n in range(len(mydata)):
    plt.scatter(mydata[n][0],mydata[n][1], color='black', s=0.2)
plt.show()

for n in range(len(mydata)):
    plt.scatter(mydata[n][0],mydata[n][1], color=colors[mydata[n][2]], s=0.2)
plt.show()

# %% [markdown]
# ### STAN Model

# %%
my_model = """
data {
 int <lower=0> N; // number of datapoints
 array[N,2] real y;  // there are 2 observables per datapoint
 real mumuA1, sigmamuA1, musigmaA1, sigmasigmaA1, 
      mumuB1, sigmamuB1, musigmaB1, sigmasigmaB1,
      mumuA2, sigmamuA2, musigmaA2, sigmasigmaA2, 
      mumuB2, sigmamuB2, musigmaB2, sigmasigmaB2; // hyperparameters for Normals that are priors for each parameter
 real t1, t2; // hyperparameter for the Dirichlet prior to the mixture coefficient pi0      
}

parameters {
  real muA1, muB1, muA2, muB2; 
  real<lower=0> sigmaA1, sigmaB1, sigmaA2, sigmaB2;
  real<lower=0, upper=1> pi0;
  simplex[2] theta;  
}

transformed parameters{
  ordered[2] muA;
  ordered[2] muB;

  //We need to know the relative order of both classes in each observable
  muA[1] = muA1;
  muA[2] = muA2;
  muB[1] = muB1;
  muB[2] = muB2;
}

model {
    vector[2] lp;
    muA1 ~ normal(mumuA1, sigmamuA1);
    sigmaA1 ~ normal(musigmaA1, sigmasigmaA1);
    muB1 ~ normal(mumuB1, sigmamuB1);
    sigmaB1 ~ normal(musigmaB1, sigmasigmaB1);    
    muA2 ~ normal(mumuA2, sigmamuA2);
    sigmaA2 ~ normal(musigmaA2, sigmasigmaA2);
    muB2 ~ normal(mumuB2, sigmamuB2);
    sigmaB2 ~ normal(musigmaB2, sigmasigmaB2);    
        
    theta ~ dirichlet([t1,t2]);
    
   for (n in 1:N) {
     lp[1] =   normal_lpdf(y[n,1] | muA1, sigmaA1)
             + normal_lpdf(y[n,2] | muB1, sigmaB1);
     lp[2] =   normal_lpdf(y[n,1] | muA2, sigmaA2)
             + normal_lpdf(y[n,2] | muB2, sigmaB2);
     target += log_mix(theta, lp);                        
     };
}
"""

# %% [markdown]
# ### Infer

# %%
# Hyperparameters that rule the parameters priors
mumuA1 = 5
sigmamuA1 = 5
musigmaA1 = 3
sigmasigmaA1 = 3 

mumuB1 = 5
sigmamuB1 = 5
musigmaB1 = 3
sigmasigmaB1 = 3 

mumuA2 = 5
sigmamuA2 = 5
musigmaA2 = 3
sigmasigmaA2 = 3 

mumuB2 = 5
sigmamuB2 = 5
musigmaB2 = 3
sigmasigmaB2 = 3 

t1 = 1
t2 = 1

# %%
passed_data = [[x[0], x[1]] for x in mydata] # don't pass the class to which belongs each datapoint

# %%
data = {'N': N,
        'y': passed_data,
        'mumuA1': mumuA1,
        'sigmamuA1': sigmamuA1,
        'musigmaA1': musigmaA1,
        'sigmasigmaA1': sigmasigmaA1, 
        'mumuB1': mumuB1,
        'sigmamuB1': sigmamuB1,
        'musigmaB1': musigmaB1,
        'sigmasigmaB1': sigmasigmaB1,
        'mumuA2': mumuA2, 
        'sigmamuA2': sigmamuA2, 
        'musigmaA2': musigmaA2, 
        'sigmasigmaA2': sigmasigmaA2,
        'mumuB2': mumuB2,
        'sigmamuB2': sigmamuB2,
        'musigmaB2': musigmaB2,
        'sigmasigmaB2': sigmasigmaB2,
        't1': t1,
        't2': t2}

# %%
model = stan.build(my_model, data=data, random_seed=0);
# Out:
# Building: found in cache, done.
# Messages from stanc:
# Warning in '/tmp/httpstan_trdf0c0s/model_53b65oip.stan', line 41, column 4: The
#     parameter theta is on the left-hand side of more than one tilde
#     statement.
# Warning: The parameter theta has no priors. This means either no prior is
#     provided, or the prior(s) depend on data variables. In the later case,
#     this may be a false positive.
# Warning: The parameter sigmaB2 has no priors. This means either no prior is
#     provided, or the prior(s) depend on data variables. In the later case,
#     this may be a false positive.
# Warning: The parameter sigmaB1 has no priors. This means either no prior is
#     provided, or the prior(s) depend on data variables. In the later case,
#     this may be a false positive.
# Warning: The parameter sigmaA2 has no priors. This means either no prior is
#     provided, or the prior(s) depend on data variables. In the later case,
#     this may be a false positive.
# Warning: The parameter sigmaA1 has no priors. This means either no prior is
#     provided, or the prior(s) depend on data variables. In the later case,
#     this may be a false positive.
# Warning: The parameter pi0 was declared but was not used in the density
#     calculation.
# Warning: The parameter muB2 has no priors. This means either no prior is
#     provided, or the prior(s) depend on data variables. In the later case,
#     this may be a false positive.
# Warning: The parameter muB1 has no priors. This means either no prior is
#     provided, or the prior(s) depend on data variables. In the later case,
#     this may be a false positive.
# Warning: The parameter muA2 has no priors. This means either no prior is
#     provided, or the prior(s) depend on data variables. In the later case,
#     this may be a false positive.
# Warning: The parameter muA1 has no priors. This means either no prior is
#     provided, or the prior(s) depend on data variables. In the later case,
#     this may be a false positive.

# %%
fit = model.sample(num_chains=4, num_samples=1000, delta=0.8)
# Out:
# Sampling:   0%
# Sampling:   0% (1/8000)
# Sampling:   0% (2/8000)
# Sampling:   0% (3/8000)
# Sampling:   4% (303/8000)
# Sampling:  13% (1002/8000)
# Sampling:  21% (1701/8000)
# Sampling:  31% (2500/8000)
# Sampling:  35% (2800/8000)
# Sampling:  51% (4100/8000)
# Sampling:  68% (5400/8000)
# Sampling:  82% (6600/8000)
# Sampling:  85% (6800/8000)
# Sampling:  86% (6900/8000)
# Sampling:  88% (7001/8000)
# Sampling:  89% (7100/8000)
# Sampling:  90% (7200/8000)
# Sampling:  91% (7300/8000)
# Sampling:  92% (7400/8000)
# Sampling:  94% (7500/8000)
# Sampling:  95% (7600/8000)
# Sampling:  96% (7700/8000)
# Sampling:  98% (7800/8000)
# Sampling:  99% (7900/8000)
# Sampling: 100% (8000/8000)
# Sampling: 100% (8000/8000), done.
# Messages received during sampling:
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is 0.0604822, but should be greater than the previous element, 0.746532 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
#   Gradient evaluation took 0.00126 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 12.6 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is 10.5322, but should be greater than the previous element, 15.0197 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 16.5208, but should be greater than the previous element, 26.8271 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.280446, but should be greater than the previous element, 0.326481 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.332864, but should be greater than the previous element, 0.926639 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is -1.92338, but should be greater than the previous element, -0.0193912 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is -1.12814, but should be greater than the previous element, 0.412867 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
#   Gradient evaluation took 0.00038 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 3.8 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is -0.942433, but should be greater than the previous element, -0.637011 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is -0.740397, but should be greater than the previous element, 0.616814 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
#   Gradient evaluation took 0.000362 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 3.62 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: log_mix: lambda[2] is -inf, but must be finite! (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 48, column 5 to column 34)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is -1.58469, but should be greater than the previous element, 1.66127 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is -1.60761, but should be greater than the previous element, 0.381508 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is 1.61101, but should be greater than the previous element, 1.8714 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is -0.482401, but should be greater than the previous element, 1.40808 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is -0.294386, but should be greater than the previous element, 1.39254 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is 1.36153, but should be greater than the previous element, 1.69846 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is -1.39099, but should be greater than the previous element, 0.00537096 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is 0.537513, but should be greater than the previous element, 1.02048 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
# warn:Rejecting initial value:
# warn:  Error evaluating the log probability at the initial value.
# warn:Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is -1.31964, but should be greater than the previous element, 1.08613 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   Gradient evaluation took 0.000366 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 3.66 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is 1.371, but should be greater than the previous element, 115.7 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is 1.4841, but should be greater than the previous element, 116.116 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is 1.38185, but should be greater than the previous element, 28.5194 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is 1.41369, but should be greater than the previous element, 6.08171 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.611281, but should be greater than the previous element, 0.677985 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is 138.234, but should be greater than the previous element, 7023.25 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muA is not a valid ordered vector. The element at 2 is 8.3169, but should be greater than the previous element, 199.01 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 20, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.780265, but should be greater than the previous element, 1.74752 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 1.08787, but should be greater than the previous element, 1.24326 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 1.308, but should be greater than the previous element, 1.31426 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.537014, but should be greater than the previous element, 0.678489 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.479225, but should be greater than the previous element, 0.609488 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.79031, but should be greater than the previous element, 0.951112 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.500239, but should be greater than the previous element, 0.508217 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.477303, but should be greater than the previous element, 0.481252 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.481637, but should be greater than the previous element, 0.483594 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.476828, but should be greater than the previous element, 0.484434 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.460307, but should be greater than the previous element, 0.462751 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.479821, but should be greater than the previous element, 0.487273 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.447715, but should be greater than the previous element, 0.455736 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.491384, but should be greater than the previous element, 0.494429 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.4942, but should be greater than the previous element, 0.498759 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.535038, but should be greater than the previous element, 0.538577 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.508164, but should be greater than the previous element, 0.511009 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.545325, but should be greater than the previous element, 0.547891 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.479931, but should be greater than the previous element, 0.488088 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.524864, but should be greater than the previous element, 0.527793 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.51361, but should be greater than the previous element, 0.523258 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.504165, but should be greater than the previous element, 0.517494 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.50931, but should be greater than the previous element, 0.509437 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.510832, but should be greater than the previous element, 0.511132 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.497902, but should be greater than the previous element, 0.498069 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.502627, but should be greater than the previous element, 0.503174 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.513077, but should be greater than the previous element, 0.513612 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.501083, but should be greater than the previous element, 0.501176 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.502768, but should be greater than the previous element, 0.502949 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.505552, but should be greater than the previous element, 0.505598 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.492133, but should be greater than the previous element, 0.492358 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.483383, but should be greater than the previous element, 0.483495 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.485261, but should be greater than the previous element, 0.486348 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.487987, but should be greater than the previous element, 0.488684 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.483438, but should be greater than the previous element, 0.484224 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.471917, but should be greater than the previous element, 0.472856 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.503972, but should be greater than the previous element, 0.507488 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.481108, but should be greater than the previous element, 0.490184 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.7109, but should be greater than the previous element, 0.725151 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.531419, but should be greater than the previous element, 0.549095 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 0.544034, but should be greater than the previous element, 0.552277 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# ...
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 2.66066, but should be greater than the previous element, 2.66165 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 2.67034, but should be greater than the previous element, 2.67088 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 2.64143, but should be greater than the previous element, 2.65569 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 2.8076, but should be greater than the previous element, 2.81027 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 2.78659, but should be greater than the previous element, 2.78709 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 2.93065, but should be greater than the previous element, 2.93681 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 2.82363, but should be greater than the previous element, 2.83691 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 2.81951, but should be greater than the previous element, 2.84294 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 2.87398, but should be greater than the previous element, 2.89202 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 2.89959, but should be greater than the previous element, 2.91439 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.20134, but should be greater than the previous element, 3.22307 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.10108, but should be greater than the previous element, 3.13659 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.16001, but should be greater than the previous element, 3.18439 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.1134, but should be greater than the previous element, 3.13147 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.11513, but should be greater than the previous element, 3.11847 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.12633, but should be greater than the previous element, 3.12768 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.10802, but should be greater than the previous element, 3.1103 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.09422, but should be greater than the previous element, 3.10087 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.09378, but should be greater than the previous element, 3.10979 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.07893, but should be greater than the previous element, 3.10545 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.08412, but should be greater than the previous element, 3.08459 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.13978, but should be greater than the previous element, 3.14075 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.10524, but should be greater than the previous element, 3.10704 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.123, but should be greater than the previous element, 3.12474 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.1412, but should be greater than the previous element, 3.14194 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: model_53b65oip_namespace::log_prob: muB is not a valid ordered vector. The element at 2 is 3.16213, but should be greater than the previous element, 3.16457 (in '/tmp/httpstan_enmczp1j/model_53b65oip.stan', line 21, column 2 to column 17)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.

# %%
df = fit.to_frame() 
df
# Out:
# parameters         lp__  accept_stat__  stepsize__  treedepth__  n_leapfrog__  \
# draws
# 0          -2708.197624       0.866912    0.442019          3.0           7.0
# 1          -2707.084567       0.945353    0.503545          3.0           7.0
# 2          -2709.149992       0.952765    0.478648          4.0          15.0
# 3          -2970.351280       0.000000    0.001526          0.0           1.0
# 4          -2705.481226       0.986514    0.442019          3.0           7.0
# ...                 ...            ...         ...          ...           ...
# 3995       -2705.700654       0.999985    0.001526          8.0         255.0
# 3996       -2707.635339       1.000000    0.442019          3.0           7.0
# 3997       -2704.042597       0.988542    0.503545          2.0           7.0
# 3998       -2705.661737       0.921936    0.478648          3.0          15.0
# 3999       -2707.397026       0.999986    0.001526         10.0        1023.0
#
# parameters  divergent__     energy__      muA1      muB1       muA2  ...  \
# draws                                                                ...
# 0                   0.0  2711.504812  8.497124  2.870478  14.181065  ...
# 1                   0.0  2709.394702  8.061695  3.115077  14.059534  ...
# 2                   0.0  2713.601653  7.439760  2.610938  13.308466  ...
# 3                   1.0  2973.132633  7.485428  6.002980   7.493588  ...
# 4                   0.0  2709.866384  8.331657  3.161790  14.217394  ...
# ...                 ...          ...       ...       ...        ...  ...
# 3995                0.0  2712.231938  8.144621  2.754794  13.889486  ...
# 3996                0.0  2713.444036  7.974779  2.975765  13.667648  ...
# 3997                0.0  2711.634473  7.861923  2.919667  14.050979  ...
# 3998                0.0  2709.840048  7.559511  2.686613  14.092975  ...
# 3999                0.0  2711.333203  7.733953  2.613550  13.939172  ...
#
# parameters   sigmaB1   sigmaA2   sigmaB2       pi0   theta.1   theta.2  \
# draws
# 0           1.916270  3.525081  2.881469  0.062924  0.309889  0.690111
# 1           2.020808  3.884705  2.973191  0.223700  0.218965  0.781035
# 2           1.782733  3.639395  3.156551  0.628390  0.188290  0.811710
# 3           3.208505  9.196437  1.397477  0.527604  0.964285  0.035715
# 4           2.166310  3.850608  2.904738  0.660303  0.296144  0.703856
# ...              ...       ...       ...       ...       ...       ...
# 3995        1.988234  3.902448  3.159377  0.520935  0.240722  0.759278
# 3996        1.721266  3.788945  3.079721  0.410194  0.263681  0.736319
# 3997        2.046626  3.789897  3.157702  0.214810  0.252748  0.747252
# 3998        1.944310  3.724081  3.029513  0.718460  0.221842  0.778158
# 3999        2.290329  3.739587  2.924825  0.525442  0.223048  0.776952
#
# parameters     muA.1      muA.2     muB.1      muB.2
# draws
# 0           8.497124  14.181065  2.870478   7.253101
# 1           8.061695  14.059534  3.115077   6.786539
# 2           7.439760  13.308466  2.610938   6.613812
# 3           7.485428   7.493588  6.002980  11.850678
# 4           8.331657  14.217394  3.161790   7.270150
# ...              ...        ...       ...        ...
# 3995        8.144621  13.889486  2.754794   6.674631
# 3996        7.974779  13.667648  2.975765   6.716260
# 3997        7.861923  14.050979  2.919667   6.866006
# 3998        7.559511  14.092975  2.686613   7.239425
# 3999        7.733953  13.939172  2.613550   7.264400
#
# [4000 rows x 22 columns]

# %%
for varname in list(df)[7:16]:
    plt.hist(df[varname], histtype='step', density=1)
    plt.axvline(x= globals()[varname])
    plt.title(varname)
    plt.show()
